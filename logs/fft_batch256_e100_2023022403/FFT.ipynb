# %%
# データセット作成

# !pip install scipy

window_size = 1024
window_num_per_clip = 40
clip_size = window_size * window_num_per_clip
fft_sum_threshold = 50

from scipy.io.wavfile import read
import glob
import os
import numpy as np

def standardization(x):
    ret = np.log(x + 1) / np.log(np.finfo(np.float32).max)
    if (np.sum(ret) == 0):
        return ret
    else:
        return ret / np.sum(ret)

if os.path.isfile("../data/arrays/clips.npy"):
    print("clips.npy exists.")
    clips = np.load("../data/arrays/clips.npy")
else:
    files = glob.glob("../data/wav44100/*")
    #files = ["../data/wav44100/3DEmbodimentFromLines.wav"]
    raw_data_list = [read(file)[1] for file in files]

    clips = np.zeros((0, clip_size), dtype=np.int16)
    for raw_data in raw_data_list:
        tmp = [raw_data[i:i + clip_size] for i in range(0, len(raw_data) - clip_size, clip_size)]
        clips = np.vstack((clips, np.array(tmp)))
    np.save("../data/arrays/clips", clips)
    
    
if os.path.isfile("../data/arrays/fft_log.npy"):
    print("fft_log.npy exists.")
    fft = np.load("../data/arrays/fft_log.npy")
else:
    fft = np.zeros((0, window_num_per_clip, window_size))
    num = 0
    for clip in clips:
        print("fft progress: clip " + str(num))
        
        fft_tmp = np.zeros((0, window_size))
        tmp = [clip[i:i + window_size] for i in range(0, len(clip) - window_size + 1, window_size)]
        for tmp2 in tmp:
            spectrum = np.abs(np.fft.fft(tmp2))
            #spectrum = standardization(spectrum)
            spectrum = np.log(x + 1) / np.log(np.finfo(np.float32).max)
            fft_tmp = np.vstack((fft_tmp, spectrum))
        fft = np.vstack((fft, fft_tmp.reshape(1, window_num_per_clip, window_size)))
        num += 1

    np.save("../data/arrays/fft_log", fft)
    
print("clips.shape: " + str(clips.shape))
print("fft.shape: " + str(fft.shape))
# Out:
# Requirement already satisfied: scipy in /usr/local/lib/python3.8/dist-packages (1.10.1)
# Requirement already satisfied: numpy<1.27.0,>=1.19.5 in /usr/local/lib/python3.8/dist-packages (from scipy) (1.23.4)
# WARNING: You are using pip version 20.2.4; however, version 23.0.1 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.
# clips.npy exists.
# fft_log.npy exists.
# clips.shape: (28576, 40960)
# fft.shape: (28576, 40, 1024)

# %%
# 学習データとテストデータに分ける

train_data_rate = 0.8
fft_sum_threshold = 50

def normalize(array):
    if (np.sum(array) == 0):
        return array
    else:
        return array / np.sum(array)

x = np.concatenate([fft[:-1, :, :], fft[1:, 0, :].reshape(fft.shape[0] - 1, 1, fft.shape[2])], 1)

clips = np.delete(clips, np.where(np.sum(x[:,0,:], axis=1) < fft_sum_threshold)[0], axis=0)
x = np.delete(x, np.where(np.sum(x[:,0,:], axis=1) < fft_sum_threshold)[0], axis=0)

x = np.apply_along_axis(normalize, 2, x)

p = np.random.permutation(len(x))
x = x[p]
clips = clips[p]

x_train = x[:int(x.shape[0] * train_data_rate), :window_num_per_clip, :].reshape(int(x.shape[0] * train_data_rate), window_num_per_clip, window_size, 1)
x_test = x[int(x.shape[0] * train_data_rate):, :window_num_per_clip, :].reshape(x.shape[0] - int(x.shape[0] * train_data_rate), window_num_per_clip, window_size, 1)
y_train = x[:int(x.shape[0] * train_data_rate), window_num_per_clip, :]
y_test = x[int(x.shape[0] * train_data_rate):, window_num_per_clip, :]

print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)

print(np.max(x_train[0]))
# Out:
# (22237, 40, 1024, 1)
# (5560, 40, 1024, 1)
# (22237, 1024)
# (5560, 1024)
# 0.0019774655252592127

# %%
def plot_history(history):
    # 精度の履歴をプロット
    plt.plot(history.history['accuracy'],"o-",label="accuracy")
    plt.plot(history.history['val_accuracy'],"o-",label="val_acc")
    plt.title('model accuracy')
    plt.xlabel('epoch')
    plt.ylabel('accuracy')
    plt.legend(loc="lower right")
    plt.show()
 
    # 損失の履歴をプロット
    plt.plot(history.history['loss'],"o-",label="loss",)
    plt.plot(history.history['val_loss'],"o-",label="val_loss")
    plt.title('model loss')
    plt.xlabel('epoch')
    plt.ylabel('loss')
    plt.legend(loc='lower right')
    plt.show()

# %%
# モデル作成

import keras

from keras.models import Sequential
from keras.layers import Activation, Dense, Dropout, Conv2D, Flatten, Input
from keras.optimizers import Adam

learning_rate = 0.0001
 
model = keras.models.Sequential()
model.add(Conv2D(3, (3, 1), activation='relu', input_shape=(window_num_per_clip, window_size, 1)))
model.add(Dropout(0.2))
model.add(Flatten())
model.add(Dense(units=512))
model.add(Activation('relu'))
model.add(Dropout(0.2))
model.add(Dense(units=1024))
model.add(Activation('softmax'))
model.compile(loss='categorical_crossentropy',optimizer=Adam(learning_rate=learning_rate),metrics=['accuracy'])

model.build()
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 38, 1024, 3)       12
#
#  dropout (Dropout)           (None, 38, 1024, 3)       0
#
#  flatten (Flatten)           (None, 116736)            0
#
#  dense (Dense)               (None, 512)               59769344
#
#  activation (Activation)     (None, 512)               0
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  dense_1 (Dense)             (None, 1024)              525312
#
#  activation_1 (Activation)   (None, 1024)              0
#
# =================================================================
# Total params: 60,294,668
# Trainable params: 60,294,668
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 学習

history = model.fit(x_train, y_train,
                    batch_size=256,
                    epochs=100,
                    verbose=1,
                    validation_data=(x_test, y_test))

model.save("../data/models/fft_batch256_e100")
# Out:
# Epoch 1/100
# 87/87 [==============================] - 53s 588ms/step - loss: 6.9193 - accuracy: 0.0231 - val_loss: 6.9148 - val_accuracy: 0.1477
# Epoch 2/100
# 87/87 [==============================] - 53s 609ms/step - loss: 6.9142 - accuracy: 0.0562 - val_loss: 6.9146 - val_accuracy: 0.1540
# Epoch 3/100
# 87/87 [==============================] - 52s 601ms/step - loss: 6.9139 - accuracy: 0.0556 - val_loss: 6.9146 - val_accuracy: 0.0000e+00
# Epoch 4/100
# 87/87 [==============================] - 52s 598ms/step - loss: 6.9138 - accuracy: 0.0590 - val_loss: 6.9147 - val_accuracy: 0.0000e+00
# Epoch 5/100
# 87/87 [==============================] - 52s 600ms/step - loss: 6.9137 - accuracy: 0.0593 - val_loss: 6.9146 - val_accuracy: 0.1540
# Epoch 6/100
# 87/87 [==============================] - 51s 591ms/step - loss: 6.9137 - accuracy: 0.0599 - val_loss: 6.9146 - val_accuracy: 5.3957e-04
# Epoch 7/100
# 87/87 [==============================] - 53s 608ms/step - loss: 6.9136 - accuracy: 0.0604 - val_loss: 6.9146 - val_accuracy: 0.1540
# Epoch 8/100
# 87/87 [==============================] - 53s 611ms/step - loss: 6.9136 - accuracy: 0.0620 - val_loss: 6.9146 - val_accuracy: 0.0000e+00
# Epoch 9/100
# 87/87 [==============================] - 52s 600ms/step - loss: 6.9136 - accuracy: 0.0650 - val_loss: 6.9146 - val_accuracy: 0.0000e+00
# Epoch 10/100
# 87/87 [==============================] - 53s 606ms/step - loss: 6.9136 - accuracy: 0.0635 - val_loss: 6.9146 - val_accuracy: 0.0203
# Epoch 11/100
# 87/87 [==============================] - 52s 602ms/step - loss: 6.9135 - accuracy: 0.0619 - val_loss: 6.9146 - val_accuracy: 0.0000e+00
# Epoch 12/100
# 87/87 [==============================] - 52s 593ms/step - loss: 6.9135 - accuracy: 0.0633 - val_loss: 6.9146 - val_accuracy: 0.1540
# Epoch 13/100
# 87/87 [==============================] - 53s 607ms/step - loss: 6.9135 - accuracy: 0.0721 - val_loss: 6.9146 - val_accuracy: 0.1540
# Epoch 14/100
# 87/87 [==============================] - 52s 599ms/step - loss: 6.9135 - accuracy: 0.0692 - val_loss: 6.9146 - val_accuracy: 0.0000e+00
# Epoch 15/100
# 87/87 [==============================] - 52s 601ms/step - loss: 6.9135 - accuracy: 0.0698 - val_loss: 6.9146 - val_accuracy: 0.1540
# Epoch 16/100
# 87/87 [==============================] - 53s 615ms/step - loss: 6.9135 - accuracy: 0.0642 - val_loss: 6.9145 - val_accuracy: 0.1540
# Epoch 17/100
# 87/87 [==============================] - 53s 603ms/step - loss: 6.9135 - accuracy: 0.0680 - val_loss: 6.9145 - val_accuracy: 0.0000e+00
# Epoch 18/100
# 87/87 [==============================] - 52s 595ms/step - loss: 6.9134 - accuracy: 0.0618 - val_loss: 6.9145 - val_accuracy: 0.1540
# Epoch 19/100
# 87/87 [==============================] - 52s 603ms/step - loss: 6.9134 - accuracy: 0.0705 - val_loss: 6.9145 - val_accuracy: 0.1540
# Epoch 20/100
# 87/87 [==============================] - 51s 589ms/step - loss: 6.9134 - accuracy: 0.0711 - val_loss: 6.9145 - val_accuracy: 0.1540
# Epoch 21/100
# 87/87 [==============================] - 51s 580ms/step - loss: 6.9134 - accuracy: 0.0707 - val_loss: 6.9145 - val_accuracy: 0.0682
# Epoch 22/100
# 87/87 [==============================] - 50s 578ms/step - loss: 6.9134 - accuracy: 0.0683 - val_loss: 6.9145 - val_accuracy: 0.0000e+00
# Epoch 23/100
# 87/87 [==============================] - 51s 580ms/step - loss: 6.9134 - accuracy: 0.0634 - val_loss: 6.9145 - val_accuracy: 0.1540
# Epoch
- val_accuracy: 0.0000e+00
# Epoch 83/100
# 87/87 [==============================] - 49s 563ms/step - loss: 6.9170 - accuracy: 0.0391 - val_loss: 6.9164 - val_accuracy: 0.1540
# Epoch 84/100
# 87/87 [==============================] - 49s 559ms/step - loss: 6.9167 - accuracy: 0.0408 - val_loss: 6.9160 - val_accuracy: 0.0000e+00
# Epoch 85/100
# 87/87 [==============================] - 49s 565ms/step - loss: 6.9188 - accuracy: 0.0238 - val_loss: 6.9183 - val_accuracy: 0.1477
# Epoch 86/100
# 87/87 [==============================] - 49s 558ms/step - loss: 6.9191 - accuracy: 0.0321 - val_loss: 6.9216 - val_accuracy: 0.0000e+00
# Epoch 87/100
# 87/87 [==============================] - 49s 559ms/step - loss: 6.9189 - accuracy: 0.0288 - val_loss: 6.9207 - val_accuracy: 0.0000e+00
# Epoch 88/100
# 87/87 [==============================] - 49s 561ms/step - loss: 6.9202 - accuracy: 0.0139 - val_loss: 6.9234 - val_accuracy: 0.0000e+00
# Epoch 89/100
# 87/87 [==============================] - 48s 557ms/step - loss: 6.9239 - accuracy: 0.0045 - val_loss: 6.9323 - val_accuracy: 0.0000e+00
# Epoch 90/100
# 87/87 [==============================] - 49s 565ms/step - loss: 6.9334 - accuracy: 0.0042 - val_loss: 6.9479 - val_accuracy: 0.0797
# Epoch 91/100
# 87/87 [==============================] - 49s 564ms/step - loss: 6.9385 - accuracy: 0.0139 - val_loss: 6.9525 - val_accuracy: 0.0049
# Epoch 92/100
# 87/87 [==============================] - 49s 559ms/step - loss: 6.9632 - accuracy: 0.0016 - val_loss: 6.9616 - val_accuracy: 0.0000e+00
# Epoch 93/100
# 87/87 [==============================] - 49s 565ms/step - loss: 7.1271 - accuracy: 0.0133 - val_loss: 7.0696 - val_accuracy: 0.0000e+00
# Epoch 94/100
# 87/87 [==============================] - 49s 564ms/step - loss: 7.0572 - accuracy: 0.0020 - val_loss: 7.1177 - val_accuracy: 0.0000e+00
# Epoch 95/100
# 87/87 [==============================] - 49s 562ms/step - loss: 7.5094 - accuracy: 0.0074 - val_loss: 9.5378 - val_accuracy: 0.0000e+00
# Epoch 96/100
# 87/87 [==============================] - 49s 558ms/step - loss: 7.9830 - accuracy: 8.5443e-04 - val_loss: 6.9248 - val_accuracy: 0.0000e+00
# Epoch 97/100
# 87/87 [==============================] - 49s 560ms/step - loss: 6.9172 - accuracy: 0.0257 - val_loss: 6.9325 - val_accuracy: 0.1540
# Epoch 98/100
# 87/87 [==============================] - 49s 565ms/step - loss: 6.9301 - accuracy: 0.0178 - val_loss: 7.0187 - val_accuracy: 0.0000e+00
# Epoch 99/100
# 87/87 [==============================] - 50s 572ms/step - loss: 7.1774 - accuracy: 0.0055 - val_loss: 7.1275 - val_accuracy: 0.0000e+00
# Epoch 100/100
# 87/87 [==============================] - 49s 566ms/step - loss: 7.0624 - accuracy: 0.0047 - val_loss: 7.0347 - val_accuracy: 0.0000e+00
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ../data/models/fft_batch256_e100/assets
# INFO:tensorflow:Assets written to: ../data/models/fft_batch256_e100/assets

# %%
# loss 遷移のプロット

import matplotlib.pyplot as plt

plot_history(history)

# %%
# 楽曲の出力

# !pip install scikit-learn

import sklearn
from sklearn.metrics.pairwise import cosine_similarity
from scipy.io import wavfile
from keras.models import load_model

model = load_model("../data/models/fft_batch256_e100")

first_index = np.random.randint(0, len(x_test))
predict_index = first_index
out = np.zeros((0, ), dtype=np.int16)

for i in range(10):
    predict = model.predict(np.array([x_test[predict_index]]))
    
    index = 0
    similar_index = 0
    cos_sim = np.inf
    for spectrum in x_test[:, 0:1, :, 0]:
        tmp_sim = cosine_similarity(predict, spectrum) 
        if cos_sim > tmp_sim:
            cos_sim = tmp_sim
            similar_index = index
        index += 1
    
    print(similar_index)
    
    predict_index = similar_index
    out = np.hstack((out, clips[predict_index + int(x.shape[0] * train_data_rate)]))
    
wavfile.write("../data/out/fft_out_1.wav", 44100, out)

first_index = np.random.randint(0, len(x_test))
predict_index = first_index
out = np.zeros((0, ), dtype=np.int16)

for i in range(10):
    predict = model.predict(np.array([x_test[predict_index]]))
    
    index = 0
    similar_index = 0
    cos_sim = np.inf
    for spectrum in x_test[:, 0:1, :, 0]:
        tmp_sim = cosine_similarity(predict, spectrum) 
        if cos_sim > tmp_sim:
            cos_sim = tmp_sim
            similar_index = index
        index += 1
    
    print(similar_index)
    
    predict_index = similar_index
    out = np.hstack((out, clips[predict_index + int(x.shape[0] * train_data_rate)]))
    
wavfile.write("../data/out/fft_out_2.wav", 44100, out)

first_index = np.random.randint(0, len(x_test))
predict_index = first_index
out = np.zeros((0, ), dtype=np.int16)

for i in range(10):
    predict = model.predict(np.array([x_test[predict_index]]))
    
    index = 0
    similar_index = 0
    cos_sim = np.inf
    for spectrum in x_test[:, 0:1, :, 0]:
        tmp_sim = cosine_similarity(predict, spectrum) 
        if cos_sim > tmp_sim:
            cos_sim = tmp_sim
            similar_index = index
        index += 1
    
    print(similar_index)
    
    predict_index = similar_index
    out = np.hstack((out, clips[predict_index + int(x.shape[0] * train_data_rate)]))
    
wavfile.write("../data/out/fft_out_3.wav", 44100, out)
# Out:
# Collecting scikit-learn
#   Downloading scikit_learn-1.2.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (9.8 MB)
#      |████████████████████████████████| 9.8 MB 137 kB/s eta 0:00:01
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.8/dist-packages (from scikit-learn) (1.23.4)
# Collecting joblib>=1.1.1
#   Downloading joblib-1.2.0-py3-none-any.whl (297 kB)
#      |████████████████████████████████| 297 kB 9.8 MB/s eta 0:00:01
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.8/dist-packages (from scikit-learn) (1.10.1)
# Collecting threadpoolctl>=2.0.0
#   Downloading threadpoolctl-3.1.0-py3-none-any.whl (14 kB)
# Installing collected packages: joblib, threadpoolctl, scikit-learn
# Successfully installed joblib-1.2.0 scikit-learn-1.2.1 threadpoolctl-3.1.0
# WARNING: You are using pip version 20.2.4; however, version 23.0.1 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.
# 1/1 [==============================] - 0s 77ms/step
# 3487
# 1/1 [==============================] - 0s 32ms/step
# 3487
# 1/1 [==============================] - 0s 32ms/step
# 3487
# 1/1 [==============================] - 0s 30ms/step
# 3487
# 1/1 [==============================] - 0s 30ms/step
# 3487
# 1/1 [==============================] - 0s 33ms/step
# 3487
# 1/1 [==============================] - 0s 29ms/step
# 3487
# 1/1 [==============================] - 0s 31ms/step
# 3487
# 1/1 [==============================] - 0s 31ms/step
# 3487
# 1/1 [==============================] - 0s 31ms/step
# 3487
# 1/1 [==============================] - 0s 30ms/step
# 3487
# 1/1 [==============================] - 0s 30ms/step
# 3487
# 1/1 [==============================] - 0s 30ms/step
# 3487
# 1/1 [==============================] - 0s 30ms/step
# 3487
# 1/1 [==============================] - 0s 30ms/step
# 3487
# 1/1 [==============================] - 0s 37ms/step
# 3487
# 1/1 [==============================] - 0s 30ms/step
# 3487
# 1/1 [==============================] - 0s 33ms/step
# 3487
# 1/1 [==============================] - 0s 30ms/step
# 3487
# 1/1 [==============================] - 0s 31ms/step
# 3487
# 1/1 [==============================] - 0s 35ms/step
# 3487
# 1/1 [==============================] - 0s 30ms/step
# 3487
# 1/1 [==============================] - 0s 30ms/step
# 3487
# 1/1 [==============================] - 0s 30ms/step
# 3487
# 1/1 [==============================] - 0s 30ms/step
# 3487
# 1/1 [==============================] - 0s 32ms/step
# 3487
# 1/1 [==============================] - 0s 31ms/step
# 3487
# 1/1 [==============================] - 0s 30ms/step
# 3487
# 1/1 [==============================] - 0s 30ms/step
# 3487
# 1/1 [==============================] - 0s 30ms/step
# 3487
