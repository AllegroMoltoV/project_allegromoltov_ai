# %%
# 環境構築

# !apt-get update
# !apt-get install -y libsndfile1-dev
# !pip install scipy
# !pip install scikit-learn
# !pip install librosa
# Out:
# Get:1 http://security.ubuntu.com/ubuntu focal-security InRelease [114 kB]
# Hit:2 http://archive.ubuntu.com/ubuntu focal InRelease
# Get:3 http://archive.ubuntu.com/ubuntu focal-updates InRelease [114 kB]
# Get:4 http://archive.ubuntu.com/ubuntu focal-backports InRelease [108 kB]
# Get:5 http://security.ubuntu.com/ubuntu focal-security/restricted amd64 Packages [1937 kB]
# Get:6 http://archive.ubuntu.com/ubuntu focal-updates/multiverse amd64 Packages [31.2 kB]
# Get:7 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 Packages [2972 kB]
# Get:8 http://archive.ubuntu.com/ubuntu focal-updates/universe amd64 Packages [1299 kB]
# Get:9 http://archive.ubuntu.com/ubuntu focal-updates/restricted amd64 Packages [2069 kB]
# Get:10 http://security.ubuntu.com/ubuntu focal-security/multiverse amd64 Packages [28.5 kB]
# Get:11 http://security.ubuntu.com/ubuntu focal-security/main amd64 Packages [2496 kB]
# Get:12 http://archive.ubuntu.com/ubuntu focal-backports/universe amd64 Packages [28.6 kB]
# Get:13 http://archive.ubuntu.com/ubuntu focal-backports/main amd64 Packages [55.2 kB]
# Get:14 http://security.ubuntu.com/ubuntu focal-security/universe amd64 Packages [1000 kB]
# Fetched 12.3 MB in 5s (2553 kB/s)
# Reading package lists... Done
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   libflac-dev libflac8 libglib2.0-0 libglib2.0-data libicu66 libogg-dev
#   libogg0 libsndfile1 libvorbis-dev libvorbis0a libvorbisenc2 libvorbisfile3
#   libxml2 pkg-config shared-mime-info tzdata xdg-user-dirs
# The following NEW packages will be installed:
#   libflac-dev libflac8 libglib2.0-0 libglib2.0-data libicu66 libogg-dev
#   libogg0 libsndfile1 libsndfile1-dev libvorbis-dev libvorbis0a libvorbisenc2
#   libvorbisfile3 libxml2 pkg-config shared-mime-info tzdata xdg-user-dirs
# 0 upgraded, 18 newly installed, 0 to remove and 52 not upgraded.
# Need to get 12.6 MB of archives.
# After this operation, 53.3 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libglib2.0-0 amd64 2.64.6-1~ubuntu20.04.4 [1287 kB]
# Get:2 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libglib2.0-data all 2.64.6-1~ubuntu20.04.4 [6052 B]
# Get:3 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 tzdata all 2022g-0ubuntu0.20.04.1 [286 kB]
# Get:4 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libicu66 amd64 66.1-2ubuntu2.1 [8515 kB]
# Get:5 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libxml2 amd64 2.9.10+dfsg-5ubuntu0.20.04.5 [640 kB]
# Get:6 http://archive.ubuntu.com/ubuntu focal/main amd64 shared-mime-info amd64 1.15-1 [430 kB]
# Get:7 http://archive.ubuntu.com/ubuntu focal/main amd64 xdg-user-dirs amd64 0.17-2ubuntu1 [48.3 kB]
# Get:8 http://archive.ubuntu.com/ubuntu focal/main amd64 libogg0 amd64 1.3.4-0ubuntu1 [24.0 kB]
# Get:9 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libflac8 amd64 1.3.3-1ubuntu0.1 [103 kB]
# Get:10 http://archive.ubuntu.com/ubuntu focal/main amd64 libogg-dev amd64 1.3.4-0ubuntu1 [161 kB]
# Get:11 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libflac-dev amd64 1.3.3-1ubuntu0.1 [151 kB]
# Get:12 http://archive.ubuntu.com/ubuntu focal/main amd64 libvorbis0a amd64 1.3.6-2ubuntu1 [87.0 kB]
# Get:13 http://archive.ubuntu.com/ubuntu focal/main amd64 libvorbisenc2 amd64 1.3.6-2ubuntu1 [70.7 kB]
# Get:14 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libsndfile1 amd64 1.0.28-7ubuntu0.1 [170 kB]
# Get:15 http://archive.ubuntu.com/ubuntu focal/main amd64 pkg-config amd64 0.29.1-0ubuntu4 [45.5 kB]
# Get:16 http://archive.ubuntu.com/ubuntu focal/main amd64 libvorbisfile3 amd64 1.3.6-2ubuntu1 [16.1 kB]
# Get:17 http://archive.ubuntu.com/ubuntu focal/main amd64 libvorbis-dev amd64 1.3.6-2ubuntu1 [316 kB]
# Get:18 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libsndfile1-dev amd64 1.0.28-7ubuntu0.1 [280 kB]
# Fetched 12.6 MB in 6s (1978 kB/s)
# debconf: delaying package configuration, since apt-utils is not installed
# Selecting previously unselected package libglib2.0-0:amd64.
# (Reading database ... 15418 files and directories currently installed.)
# Preparing to unpack .../00-libglib2.0-0_2.64.6-1~ubuntu20.04.4_amd64.deb ...
# Unpacking libglib2.0-0:amd64 (2.64.6-1~ubuntu20.04.4) ...
# Selecting previously unselected package libglib2.0-data.
# Preparing to unpack .../01-libglib2.0-data_2.64.6-1~ubuntu20.04.4_all.deb ...
# Unpacking libglib2.0-data (2.64.6-1~ubuntu20.04.4) ...
# Selecting previously unselected package tzdata.
# Preparing to unpack .../02-tzdata_2022g-0ubuntu0.20.04.1_all.deb ...
# Unpacking tzdata (2022g-0ubuntu0.20.04.1) ...
# Selecting previously unselected package libicu66:amd64.
# Preparing to unpack .../03-libicu66_66.1-2ubuntu2.1_amd64.deb ...
# Unpacking libicu66:amd64 (66.1-2ubuntu2.1) ...
# Selecting previously unselected package libxml2:amd64.
# Preparing to unpack .../04-libxml2_2.9.10+dfsg-5ubuntu0.20.04.5_amd64.deb ...
# Unpacking libxml2:amd64 (2.9.10+dfsg-5ubuntu0.20.04.5) ...
# Selecting previously unselected package shared-mime-info.
# Preparing to unpack .../05-shared-mime-info_1.15-1_amd64.deb ...
# Unpacking shared-mime-info (1.15-1) ...
# Selecting previously unselected package xdg-user-dirs.
# Preparing to unpack .../06-xdg-user-dirs_0.17-2ubuntu1_amd64.deb ...
# Unpacking xdg-user-dirs (0.17-2ubuntu1) ...
# Selecting previously unselected package libogg0:amd64.
# Preparing to unpack .../07-libogg0_1.3.4-0ubuntu1_amd64.deb ...
# Unpacking libogg0:amd64 (1.3.4-0ubuntu1) ...
# Selecting previously unselected package libflac8:amd64.
# Preparing to unpack .../08-libflac8_1.3.3-1ubuntu0.1_amd64.deb ...
# Unpacking libflac8:amd64 (1.3.3-1ubuntu0.1) ...
# Selecting previously unselected package libogg-dev:amd64.
# Preparing to unpack .../09-libogg-dev_1.3.4-0ubuntu1_amd64.deb ...
# Unpacking libogg-dev:amd64 (1.3.4-0ubuntu1) ...
# Selecting previously unselected package libflac-dev:amd64.
# Preparing to unpack .../10-libflac-dev_1.3.3-1ubuntu0.1_amd64.deb ...
# Unpacking libflac-dev:amd64 (1.3.3-1ubuntu0.1) ...
# Selecting previously unselected package libvorbis0a:amd64.
# Preparing to unpack .../11-libvorbis0a_1.3.6-2ubuntu1_amd64.deb ...
# Unpacking libvorbis0a:amd64 (1.3.6-2ubuntu1) ...
# Selecting previously unselected package libvorbisenc2:amd64.
# Preparing to unpack .../12-libvorbisenc2_1.3.6-2ubuntu1_amd64.deb ...
# Unpacking libvorbisenc2:amd64 (1.3.6-2ubuntu1) ...
# Selecting previously unselected package libsndfile1:amd64.
# Preparing to unpack .../13-libsndfile1_1.0.28-7ubuntu0.1_amd64.deb ...
# Unpacking libsndfile1:amd64 (1.0.28-7ubuntu0.1) ...
# Selecting previously unselected package pkg-config.
# Preparing to unpack .../14-pkg-config_0.29.1-0ubuntu4_amd64.deb ...
# Unpacking pkg-config (0.29.1-0ubuntu4) ...
# Selecting previously unselected package libvorbisfile3:amd64.
# Preparing to unpack .../15-libvorbisfile3_1.3.6-2ubuntu1_amd64.deb ...
# Unpacking libvorbisfile3:amd64 (1.3.6-2ubuntu1) ...
# Selecting previously unselected package libvorbis-dev:amd64.
# Preparing to unpack .../16-libvorbis-dev_1.3.6-2ubuntu1_amd64.deb ...
# Unpacking libvorbis-dev:amd64 (1.3.6-2ubuntu1) ...
# Selecting previously unselected package libsndfile1-dev.
# Preparing to unpack .../17-libsndfile1-dev_1.0.28-7ubuntu0.1_amd64.deb ...
# Unpacking libsndfile1-dev (1.0.28-7ubuntu0.1) ...
# Setting up libogg0:amd64 (1.3.4-0ubuntu1) ...
# Setting up xdg-user-dirs (0.17-2ubuntu1) ...
# Setting up libglib2.0-0:amd64 (2.64.6-1~ubuntu20.04.4) ...
# No schema files found: doing nothing.
# Setting up libogg-dev:amd64 (1.3.4-0ubuntu1) ...
# Setting up libflac8:amd64 (1.3.3-1ubuntu0.1) ...
# Setting up tzdata (2022g-0ubuntu0.20.04.1) ...
#
# Current default time zone: 'Etc/UTC'
# Local time is now:      Mon Feb 27 09:01:03 UTC 2023.
# Universal Time is now:  Mon Feb 27 09:01:03 UTC 2023.
# Run 'dpkg-reconfigure tzdata' if you wish to change it.
#
# Setting up libglib2.0-data (2.64.6-1~ubuntu20.04.4) ...
# Setting up libvorbis0a:amd64 (1.3.6-2ubuntu1) ...
# Setting up pkg-config (0.29.1-0ubuntu4) ...
# Setting up libvorbisenc2:amd64 (1.3.6-2ubuntu1) ...
# Setting up libflac-dev:amd64 (1.3.3-1ubuntu0.1) ...
# Setting up libicu66:amd64 (66.1-2ubuntu2.1) ...
# Setting up libvorbisfile3:amd64 (1.3.6-2ubuntu1) ...
# Setting up libsndfile1:amd64 (1.0.28-7ubuntu0.1) ...
# Setting up libxml2:amd64 (2.9.10+dfsg-5ubuntu0.20.04.5) ...
# Setting up libvorbis-dev:amd64 (1.3.6-2ubuntu1) ...
# Setting up libsndfile1-dev (1.0.28-7ubuntu0.1) ...
# Setting up shared-mime-info (1.15-1) ...
# Processing triggers for libc-bin (2.31-0ubuntu9.9) ...
# Collecting scipy
#   Downloading scipy-1.10.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (34.5 MB)
#      |████████████████████████████████| 34.5 MB 15.9 MB/s eta 0:00:01     |███████████████████▊            | 21.3 MB 14.4 MB/s eta 0:00:01     |█████████████████████████████▋  | 32.0 MB 15.9 MB/s eta 0:00:01
# Requirement already satisfied: numpy<1.27.0,>=1.19.5 in /usr/local/lib/python3.8/dist-packages (from scipy) (1.23.4)
# Installing collected packages: scipy
# Successfully installed scipy-1.10.1
# WARNING: You are using pip version 20.2.4; however, version 23.0.1 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.
# Collecting scikit-learn
#   Downloading scikit_learn-1.2.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (9.8 MB)
#      |████████████████████████████████| 9.8 MB 10.6 MB/s eta 0:00:01
# Collecting joblib>=1.1.1
#   Downloading joblib-1.2.0-py3-none-any.whl (297 kB)
#      |████████████████████████████████| 297 kB 10.6 MB/s eta 0:00:01
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.8/dist-packages (from scikit-learn) (1.10.1)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.8/dist-packages (from scikit-learn) (1.23.4)
# Collecting threadpoolctl>=2.0.0
#   Downloading threadpoolctl-3.1.0-py3-none-any.whl (14 kB)
# Installing collected packages: joblib, threadpoolctl, scikit-learn
# Successfully installed joblib-1.2.0 scikit-learn-1.2.1 threadpoolctl-3.1.0
# WARNING: You are using pip version 20.2.4; however, version 23.0.1 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.
# Collecting librosa
#   Downloading librosa-0.10.0-py3-none-any.whl (252 kB)
#      |████████████████████████████████| 252 kB 9.5 MB/s eta 0:00:01
# Collecting numba>=0.51.0
#   Downloading numba-0.56.4-cp38-cp38-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (3.5 MB)
#      |████████████████████████████████| 3.5 MB 9.7 MB/s eta 0:00:01
# Collecting msgpack>=1.0
#   Downloading msgpack-1.0.4-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (322 kB)
#      |████████████████████████████████| 322 kB 9.1 MB/s eta 0:00:01
# Requirement already satisfied: scipy>=1.2.0 in /usr/local/lib/python3.8/dist-packages (from librosa) (1.10.1)
# Requirement already satisfied: typing-extensions>=4.1.1 in /usr/local/lib/python3.8/dist-packages (from librosa) (4.4.0)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.8/dist-packages (from librosa) (5.1.1)
# Collecting soxr>=0.3.2
#   Downloading soxr-0.3.3-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 10.4 MB/s eta 0:00:01
# Collecting lazy-loader>=0.1
#   Downloading lazy_loader-0.1-py3-none-any.whl (8.6 kB)
# Requirement already satisfied: scikit-learn>=0.20.0 in /usr/local/lib/python3.8/dist-packages (from librosa) (1.2.1)
# Collecting audioread>=2.1.9
#   Downloading audioread-3.0.0.tar.gz (377 kB)
#      |████████████████████████████████| 377 kB 11.6 MB/s eta 0:00:01
# Requirement already satisfied: numpy>=1.20.3 in /usr/local/lib/python3.8/dist-packages (from librosa) (1.23.4)
# Collecting soundfile>=0.12.1
#   Downloading soundfile-0.12.1-py2.py3-none-any.whl (24 kB)
# Requirement already satisfied: joblib>=0.14 in /usr/local/lib/python3.8/dist-packages (from librosa) (1.2.0)
# Collecting pooch>=1.0
#   Downloading pooch-1.6.0-py3-none-any.whl (56 kB)
#      |████████████████████████████████| 56 kB 489 kB/s eta 0:00:011
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from numba>=0.51.0->librosa) (65.5.1)
# Requirement already satisfied: importlib-metadata; python_version < "3.9" in /usr/local/lib/python3.8/dist-packages (from numba>=0.51.0->librosa) (5.0.0)
# Collecting llvmlite<0.40,>=0.39.0dev0
#   Downloading llvmlite-0.39.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (34.6 MB)
#      |████████████████████████████████| 34.6 MB 47 kB/s s eta 0:00:01
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from scikit-learn>=0.20.0->librosa) (3.1.0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.8/dist-packages (from soundfile>=0.12.1->librosa) (1.15.1)
# Collecting appdirs>=1.3.0
#   Downloading appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from pooch>=1.0->librosa) (21.3)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.8/dist-packages (from pooch>=1.0->librosa) (2.28.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.8/dist-packages (from importlib-metadata; python_version < "3.9"->numba>=0.51.0->librosa) (3.10.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.8/dist-packages (from cffi>=1.0->soundfile>=0.12.1->librosa) (2.21)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging>=20.0->pooch>=1.0->librosa) (3.0.9)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests>=2.19.0->pooch>=1.0->librosa) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests>=2.19.0->pooch>=1.0->librosa) (2022.9.24)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests>=2.19.0->pooch>=1.0->librosa) (1.26.12)
# Requirement already satisfied: charset-normalizer<3,>=2 in /usr/local/lib/python3.8/dist-packages (from requests>=2.19.0->pooch>=1.0->librosa) (2.1.1)
# Building wheels for collected packages: audioread
#   Building wheel for audioread (setup.py) ... done
#   Created wheel for audioread: filename=audioread-3.0.0-py3-none-any.whl size=23702 sha256=3ebea471cec54b48c8bd37922236b32d317f9c767a30e4b32e01dbac30a75e4e
#   Stored in directory: /root/.cache/pip/wheels/0a/ed/be/49df2538fca496690a024a4374455584d65c2afd6fc3d6e9c7
# Successfully built audioread
# Installing collected packages: llvmlite, numba, msgpack, soxr, lazy-loader, audioread, soundfile, appdirs, pooch, librosa
# Successfully installed appdirs-1.4.4 audioread-3.0.0 lazy-loader-0.1 librosa-0.10.0 llvmlite-0.39.1 msgpack-1.0.4 numba-0.56.4 pooch-1.6.0 soundfile-0.12.1 soxr-0.3.3
# WARNING: You are using pip version 20.2.4; however, version 23.0.1 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.

# %%
# clips 作成

SAMPLING_RATE = 44100 # 変更不可

clip_size = 81920 # 楽曲を再構築するパーツ1つあたりの大きさ
window_size = 10240 # CQT_CHROMA を取得するのに使用するサンプル数
hop_size = 640 # window をずらすときの大きさ

from scipy.io.wavfile import read, write
import glob
import os
import numpy as np
import librosa
import sys

if os.path.isfile("../data/out/clips.wav"):
    print("../data/out/clips.wav exists.")
    files = ["../data/out/clips.wav"]
else:
    # clips.npy をもとにデータを作成する 
    if os.path.isfile("../data/arrays/clips.npy"):
        print("loading ../data/arrays/clips.npy ...")
        clips = np.load("../data/arrays/clips.npy")
        print("creating ../data/out/clips.wav ...")
        write("../data/out/clips.wav", SAMPLING_RATE, clips.reshape((clips.shape[0] * clips.shape[1], )))
        files = ["../data/out/clips.wav"]
        
    # clips,npy がないとき /data/wav44100 内の WAV ファイルを参照する
    else:
        files = glob.glob("../data/wav44100/*.wav")
        #files = ["../data/wav44100/3DEmbodimentFromLines.wav"] # デバッグ用 
        
if len(files) == 0:
    print("WAV ファイルが見つかりませんでした。")
    sys.exit(1)
        
clips_filename = "../data/arrays/c" + str(clip_size) + "_f32_clips"

if os.path.isfile(clips_filename + ".npy"):
    print("loading " + clips_filename + ".npy ...")
    clips = np.load(clips_filename + ".npy")
else:
    print("creating " + clips_filename + ".npy ...")
    raw_data_list = [librosa.load(file, sr=SAMPLING_RATE)[0] for file in files] # 左の音だけ使う

    clips = np.zeros((0, clip_size), dtype=np.float32)
    for raw_data in raw_data_list:
        tmp = [raw_data[i:i + clip_size] for i in range(0, len(raw_data) - clip_size, clip_size)]
        clips = np.vstack((clips, np.array(tmp)))
    np.save(clips_filename, clips)

print("The clip array has " + str(clips.shape[0]) + " clips.")
# Out:
# ../data/out/clips.wav exists.
# loading ../data/arrays/c81920_f32_clips.npy ...
# The clip array has 14260 clips.

# %%
# cqt 作成

n_bins = 84

cqt_filename = clips_filename + "_w" + str(window_size) + "_h" + str(hop_size) + "_cqts"

if os.path.isfile(cqt_filename + ".npy"):
    print("loading " + cqt_filename + ".npy ...")
    cqts = np.load(cqt_filename + ".npy")
else:
    print("creating " + cqt_filename + ".npy ...")
    num = 0
    for clip in clips:
        print("cqt progress: clip " + str(num + 1) + " / " + str(len(clips)))
        
        tmp_cqt = librosa.cqt(clip, sr=SAMPLING_RATE, hop_length=hop_size, n_bins=n_bins)
        tmp_cqt = tmp_cqt.reshape((1, tmp_cqt.shape[0], tmp_cqt.shape[1]))
        
        if num == 0:
            cqts = tmp_cqt
        else:
            cqts = np.vstack((cqts, tmp_cqt))
            
        num += 1

    np.save(cqt_filename, cqts)
    
print("The cqt array has " + str(cqts.shape[0]) + " cqts.")
print("cqts.shape: " + str(cqts.shape))
print("Type(cqts[0][0][0]): " + str(type(cqts[0][0][0])))
print("np.max(cqts[0][0]): " + str(np.max(cqts[0][0])))
# Out:
# loading ../data/arrays/c81920_f32_clips_w10240_h640_cqts.npy ...
# The cqt array has 14260 cqts.
# cqts.shape: (14260, 84, 129)
# Type(cqts[0][0][0]): <class 'numpy.complex64'>
# np.max(cqts[0][0]): (0.021538047+0.007131239j)

# %%
# cqt_choroma 作成

def Preprocessing(array):
    array = np.abs(array)
    array = np.log(array + 1)
    array = array / np.log(np.finfo(np.float32).max)
    array = array.T
    return array

cqt_chroma_filename = clips_filename + "_w" + str(window_size) + "_h" + str(hop_size) + "_cqt_chromas"

if os.path.isfile(cqt_chroma_filename + ".npy"):
    print("loading " + cqt_chroma_filename + ".npy ...")
    cqt_chromas= np.load(cqt_chroma_filename + ".npy")
else:
    print("creating " + cqt_chroma_filename + ".npy ...")
    num = 0
    for cqt in cqts:
        print("cqt_chroma progress: clip " + str(num + 1) + " / " + str(len(cqts)))
        
        tmp_cqt_chroma = librosa.feature.chroma_cqt(C=cqt, sr=SAMPLING_RATE)
        tmp_cqt_chroma = Preprocessing(tmp_cqt_chroma)
        tmp_cqt_chroma = tmp_cqt_chroma.reshape((1, tmp_cqt_chroma.shape[0], tmp_cqt_chroma.shape[1]))
        
        if (num == 0):
            cqt_chromas = tmp_cqt_chroma
        else:
            cqt_chromas = np.vstack((cqt_chromas, tmp_cqt_chroma))
            
        num += 1

    np.save(cqt_chroma_filename, cqt_chromas)
    
print("The cqt_chroma array has " + str(cqt_chromas.shape[0]) + " cqt_chromas.")
print("cqt_chromas.shape: " + str(cqt_chromas.shape)) # clip 番号、window 番号、 chroma 番号 になる
print("Type(cqt_chromas[0][0][0]): " + str(type(cqt_chromas[0][0][0])))
print("np.max(cqt_chromas[0][0]): " + str(np.max(cqt_chromas[0][0])))
# Out:
# loading ../data/arrays/c81920_f32_clips_w10240_h640_cqt_chromas.npy ...
# The cqt_chroma array has 14260 cqt_chromas.
# cqt_chromas.shape: (14260, 129, 12)
# Type(cqt_chromas[0][0][0]): <class 'numpy.float32'>
# np.max(cqt_chromas[0][0]): 0.0078125

# %%
# 学習データとテストデータに分ける

def normalize(array):
    if (np.sum(array) == 0):
        return array
    else:
        return array / np.sum(array)
    
test_data_rate = 0.2
window_num_per_clip = cqt_chromas.shape[1]

cqt_chroma_sum_threshold = 0.01 # 次の window の sum が閾値に満たないときに除外します

cqt_chromas = np.concatenate([cqt_chromas[:-1, :, :], cqt_chromas[1:, 0, :].reshape(cqt_chromas.shape[0] - 1, 1, cqt_chromas.shape[2])], 1)

clips = np.delete(clips, np.where(np.sum(cqt_chromas[:,-1,:], axis=1) < cqt_chroma_sum_threshold)[0], axis=0)
cqt_chromas = np.delete(cqt_chromas, np.where(np.sum(cqt_chromas[:,-1,:], axis=1) < cqt_chroma_sum_threshold)[0], axis=0)

p = np.random.permutation(len(cqt_chromas))
cqt_chromas = cqt_chromas[p]
clips = clips[p]

x_test = cqt_chromas[:int(cqt_chromas.shape[0] * test_data_rate), :window_num_per_clip, :].reshape(int(cqt_chromas.shape[0] * test_data_rate), window_num_per_clip, 12, 1)
x_train = cqt_chromas[int(cqt_chromas.shape[0] * test_data_rate):, :window_num_per_clip, :].reshape(cqt_chromas.shape[0] - int(cqt_chromas.shape[0] * test_data_rate), window_num_per_clip, 12, 1)
y_test =  np.apply_along_axis(normalize, 1, cqt_chromas[:int(cqt_chromas.shape[0] * test_data_rate), window_num_per_clip, :])
y_train = np.apply_along_axis(normalize, 1, cqt_chromas[int(cqt_chromas.shape[0] * test_data_rate):, window_num_per_clip, :])

print("x_train.shape: " + str(x_train.shape))
print("x_test.shape: " + str(x_test.shape))
print("y_train.shape: " + str(y_train.shape))
print("y_test.shape: " + str(y_test.shape))
# Out:
# x_train.shape: (11184, 129, 12, 1)
# x_test.shape: (2796, 129, 12, 1)
# y_train.shape: (11184, 12)
# y_test.shape: (2796, 12)

# %%
def plot_history(history):
    # 精度の履歴をプロット
    plt.plot(history.history['accuracy'],"o-",label="accuracy")
    plt.plot(history.history['val_accuracy'],"o-",label="val_acc")
    plt.title('model accuracy')
    plt.xlabel('epoch')
    plt.ylabel('accuracy')
    plt.legend(loc="lower right")
    plt.show()
 
    # 損失の履歴をプロット
    plt.plot(history.history['loss'],"o-",label="loss",)
    plt.plot(history.history['val_loss'],"o-",label="val_loss")
    plt.title('model loss')
    plt.xlabel('epoch')
    plt.ylabel('loss')
    plt.legend(loc='lower right')
    plt.show()

# %%
# モデル作成

chroma_size = cqt_chromas.shape[2]

import keras

from keras.models import Sequential
from keras.layers import Activation, Dense, Dropout, Conv2D, Flatten, Input, MaxPooling2D
from keras.optimizers import Adam

learning_rate = 0.0001
 
model = keras.models.Sequential()
model.add(Conv2D(32, (3, 1), activation="relu", input_shape=(window_num_per_clip, chroma_size, 1)))
model.add(MaxPooling2D(pool_size=(2, 1)))
model.add(Dropout(0.5))
model.add(Conv2D(64, (3, 1), activation="relu"))
model.add(MaxPooling2D(pool_size=(2, 1)))
model.add(Dropout(0.5))
model.add(Conv2D(128, (3, 1), activation="relu"))
model.add(MaxPooling2D(pool_size=(2, 1)))
model.add(Dropout(0.5))
model.add(Flatten())
model.add(Dense(units=chroma_size))
model.add(Activation('softmax'))
model.compile(loss='categorical_crossentropy',optimizer=Adam(learning_rate=learning_rate),metrics=['accuracy'])

model.build()
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 127, 12, 32)       128
#
#  max_pooling2d (MaxPooling2D  (None, 63, 12, 32)       0
#  )
#
#  dropout (Dropout)           (None, 63, 12, 32)        0
#
#  conv2d_1 (Conv2D)           (None, 61, 12, 64)        6208
#
#  max_pooling2d_1 (MaxPooling  (None, 30, 12, 64)       0
#  2D)
#
#  dropout_1 (Dropout)         (None, 30, 12, 64)        0
#
#  conv2d_2 (Conv2D)           (None, 28, 12, 128)       24704
#
#  max_pooling2d_2 (MaxPooling  (None, 14, 12, 128)      0
#  2D)
#
#  dropout_2 (Dropout)         (None, 14, 12, 128)       0
#
#  flatten (Flatten)           (None, 21504)             0
#
#  dense (Dense)               (None, 12)                258060
#
#  activation (Activation)     (None, 12)                0
#
# =================================================================
# Total params: 289,100
# Trainable params: 289,100
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 学習
batch_size = 64
epochs = 100
model_name = "cqt_chroma_batch" + str(batch_size) + "_e" + str(epochs)

history = model.fit(x_train, y_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=1,
                    validation_data=(x_test, y_test))

model.save("../data/models/" + model_name)
# Out:
# Epoch 1/100
# 175/175 [==============================] - 13s 70ms/step - loss: 2.4777 - accuracy: 0.1438 - val_loss: 2.4776 - val_accuracy: 0.0987
# Epoch 2/100
# 175/175 [==============================] - 11s 62ms/step - loss: 2.4768 - accuracy: 0.1460 - val_loss: 2.4765 - val_accuracy: 0.1516
# Epoch 3/100
# 175/175 [==============================] - 10s 58ms/step - loss: 2.4766 - accuracy: 0.1479 - val_loss: 2.4769 - val_accuracy: 0.1516
# Epoch 4/100
# 175/175 [==============================] - 10s 59ms/step - loss: 2.4763 - accuracy: 0.1483 - val_loss: 2.4761 - val_accuracy: 0.1516
# Epoch 5/100
# 175/175 [==============================] - 10s 60ms/step - loss: 2.4759 - accuracy: 0.1482 - val_loss: 2.4763 - val_accuracy: 0.1516
# Epoch 6/100
# 175/175 [==============================] - 10s 59ms/step - loss: 2.4738 - accuracy: 0.1506 - val_loss: 2.4719 - val_accuracy: 0.1581
# Epoch 7/100
# 175/175 [==============================] - 10s 59ms/step - loss: 2.4650 - accuracy: 0.1816 - val_loss: 2.4595 - val_accuracy: 0.2057
# Epoch 8/100
# 175/175 [==============================] - 10s 59ms/step - loss: 2.4543 - accuracy: 0.2071 - val_loss: 2.4504 - val_accuracy: 0.2182
# Epoch 9/100
# 175/175 [==============================] - 10s 58ms/step - loss: 2.4503 - accuracy: 0.2165 - val_loss: 2.4494 - val_accuracy: 0.2182
# Epoch 10/100
# 175/175 [==============================] - 10s 59ms/step - loss: 2.4473 - accuracy: 0.2251 - val_loss: 2.4481 - val_accuracy: 0.2357
# Epoch 11/100
# 175/175 [==============================] - 10s 58ms/step - loss: 2.4450 - accuracy: 0.2278 - val_loss: 2.4461 - val_accuracy: 0.2411
# Epoch 12/100
# 175/175 [==============================] - 10s 59ms/step - loss: 2.4433 - accuracy: 0.2299 - val_loss: 2.4462 - val_accuracy: 0.2386
# Epoch 13/100
# 175/175 [==============================] - 10s 60ms/step - loss: 2.4414 - accuracy: 0.2354 - val_loss: 2.4426 - val_accuracy: 0.2414
# Epoch 14/100
# 175/175 [==============================] - 10s 60ms/step - loss: 2.4403 - accuracy: 0.2386 - val_loss: 2.4423 - val_accuracy: 0.2382
# Epoch 15/100
# 175/175 [==============================] - 10s 59ms/step - loss: 2.4393 - accuracy: 0.2386 - val_loss: 2.4418 - val_accuracy: 0.2421
# Epoch 16/100
# 175/175 [==============================] - 10s 60ms/step - loss: 2.4376 - accuracy: 0.2465 - val_loss: 2.4426 - val_accuracy: 0.2339
# Epoch 17/100
# 175/175 [==============================] - 11s 60ms/step - loss: 2.4373 - accuracy: 0.2414 - val_loss: 2.4419 - val_accuracy: 0.2386
# Epoch 18/100
# 175/175 [==============================] - 11s 61ms/step - loss: 2.4365 - accuracy: 0.2392 - val_loss: 2.4410 - val_accuracy: 0.2432
# Epoch 19/100
# 175/175 [==============================] - 11s 61ms/step - loss: 2.4354 - accuracy: 0.2484 - val_loss: 2.4412 - val_accuracy: 0.2450
# Epoch 20/100
# 175/175 [==============================] - 11s 61ms/step - loss: 2.4345 - accuracy: 0.2429 - val_loss: 2.4413 - val_accuracy: 0.2471
# Epoch 21/100
# 175/175 [==============================] - 11s 60ms/step - loss: 2.4343 - accuracy: 0.2488 - val_loss: 2.4410 - val_accuracy: 0.2514
# Epoch 22/100
# 175/175 [==============================] - 11s 60ms/step - loss: 2.4335 - accuracy: 0.2392 - val_loss: 2.4405 - val_accuracy: 0.2532
# Epoch 23/100
# 175/175 [==============================] - 10s 60ms/step - loss: 2.4327 - accuracy: 0.2529 - val_loss: 2.4397 - val_accuracy: 0.2493
# Epoch 24/100
# 175/175 [==============================] - 10s 60ms/step - loss: 2.4324 - accuracy: 0.2483 - val_loss: 2.4386 - val_accuracy: 0.2514
# Epoch 25/100
# 175/175 [==============================] - 10s 60ms/step - loss: 2.4321 - accuracy: 0.2483 - val_loss: 2.4393 - val_accuracy: 0.2468
# Epoch 26/100
# 175/175 [==============================] - 11s 60ms/step - loss: 2.4311 - accuracy: 0.2474 - val_loss: 2.4384 - val_accuracy: 0.2493
# Epoch 27/100
# 175/175 [==============================] - 10s 60ms/step - loss: 2.4306 - accuracy: 0.2513 - val_loss: 2.4390 - val_accuracy: 0.2479
# Epoch 28/100
# 175/175 [==============================] - 11s 60ms/step - loss: 2.4306 - accuracy: 0.2513 - val_loss: 2.4398 - val_accuracy: 0.2532
# Epoch 29/100
# 175/175 [==============================] - 11s 60ms/step - loss: 2.4294 - accuracy: 0.2517 - val_loss: 2.4388 - val_accuracy: 0.2471
# Epoch 30/100
# 175/175 [==============================] - 11s 61ms/step - loss: 2.4290 - accuracy: 0.2527 - val_loss: 2.4377 - val_accuracy: 0.2536
# Epoch 31/100
# 175/175 [==============================] - 10s 60ms/step - loss: 2.4284 - accuracy: 0.2509 - val_loss: 2.4385 - val_accuracy: 0.2521
# Epoch 32/100
# 175/175 [==============================] - 11s 60ms/step - loss: 2.4279 - accuracy: 0.2524 - val_loss: 2.4380 - val_accuracy: 0.2457
# Epoch 33/100
# 175/175 [==============================] - 11s 61ms/step - loss: 2.4278 - accuracy: 0.2530 - val_loss: 2.4376 - val_accuracy: 0.2489
# Epoch 34/100
# 175/175 [==============================] - 10s 60ms/step - loss: 2.4272 - accuracy: 0.2554 - val_loss: 2.4379 - val_accuracy: 0.2421
# Epoch 35/100
# 175/175 [==============================] - 11s 60ms/step - loss: 2.4265 - accuracy: 0.2513 - val_loss: 2.4391 - val_accuracy: 0.2600
# Epoch 36/100
# 175/175 [==============================] - 11s 60ms/step - loss: 2.4254 - accuracy: 0.2618 - val_loss: 2.4382 - val_accuracy: 0.2500
# Epoch 37/100
# 175/175 [==============================] - 11s 60ms/step - loss: 2.4253 - accuracy: 0.2531 - val_loss: 2.4385 - val_accuracy: 0.2539
# Epoch 38/100
# 175/175 [==============================] - 11s 60ms/step - loss: 2.4241 - accuracy: 0.2603 - val_loss: 2.4375 - val_accuracy: 0.2486
# Epoch 39/100
# 175/175 [==============================] - 11s 61ms/step - loss: 2.4241 - accuracy: 0.2571 - val_loss: 2.4380 - val_accuracy: 0.2493
# Epoch 40/100
# 175/175 [==============================] - 11s 61ms/step - loss: 2.4235 - accuracy: 0.2577 - val_loss: 2.4380 - val_accuracy: 0.2539
# Epoch 41/100
# 175/175 [==============================] - 11s 60ms/step - loss: 2.4227 - accuracy: 0.2544 - val_loss: 2.4388 - val_accuracy: 0.2500
# Epoch 42/100
# 175/175 [==============================] - 11s 61ms/step - loss: 2.4230 - accuracy: 0.2634 - val_loss: 2.4383 - val_accuracy: 0.2486
# Epoch 43/100
# 175/175 [==============================] - 11s 61ms/step - loss: 2.4224 - accuracy: 0.2593 - val_loss: 2.4370 - val_accuracy: 0.2554
# Epoch 44/100
# 175/175 [==============================] - 11s 61ms/step - loss: 2.4219 - accuracy: 0.2569 - val_loss: 2.4385 - val_accuracy: 0.2436
# Epoch 45/100
# 175/175 [==============================] - 11s 61ms/step - loss: 2.4205 - accuracy: 0.2619 - val_loss: 2.4377 - val_accuracy: 0.2579
# Epoch 46/100
# 175/175 [==============================] - 10s 59ms/step - loss: 2.4206 - accuracy: 0.2633 - val_loss: 2.4378 - val_accuracy: 0.2464
# Epoch 47/100
# 175/175 [==============================] - 10s 59ms/step - loss: 2.4193 - accuracy: 0.2637 - val_loss: 2.4372 - val_accuracy: 0.2546
# Epoch 48/100
# 175/175 [==============================] - 10s 59ms/step - loss: 2.4196 - accuracy: 0.2532 - val_loss: 2.4374 - val_accuracy: 0.2532
# Epoch 49/100
# 175/175 [==============================] - 10s 60ms/step - loss: 2.4186 - accuracy: 0.2635 - val_loss: 2.4369 - val_accuracy: 0.2521
# Epoch 50/100
# 175/175 [==============================] - 11s 61ms/step - loss: 2.4190 - accuracy: 0.2620 - val_loss: 2.4377 - val_accuracy: 0.2536
# Epoch 51/100
# 175/175 [==============================] - 10s 60ms/step - loss: 2.4185 - accuracy: 0.2631 - val_loss: 2.4376 - val_accuracy: 0.2554
# Epoch 52/100
# 175/175 [==============================] - 11s 60ms/step - loss: 2.4168 - accuracy: 0.2657 - val_loss: 2.4378 - val_accuracy: 0.2575
# Epoch 53/100
# 175/175 [==============================] - 11s 61ms/step - loss: 2.4173 - accuracy: 0.2656 - val_loss: 2.4377 - val_accuracy: 0.2457
# Epoch 54/100
# 175/175 [==============================] - 10s 59ms/step - loss: 2.4161 - accuracy: 0.2648 - val_loss: 2.4376 - val_accuracy: 0.2546
# Epoch 55/100
# 175/175 [==============================] - 11s 60ms/step - loss: 2.4166 - accuracy: 0.2616 - val_loss: 2.4375 - val_accuracy: 0.2564
# Epoch 56/100
# 175/175 [==============================] - 11s 60ms/step - loss: 2.4161 - accuracy: 0.2644 - val_loss: 2.4384 - val_accuracy: 0.2561
# Epoch 57/100
# 175/175 [==============================] - 10s 60ms/step - loss: 2.4152 - accuracy: 0.2684 - val_loss: 2.4374 - val_accuracy: 0.2496
# Epoch 58/100
# 175/175 [==============================] - 10s 59ms/step - loss: 2.4148 - accuracy: 0.2659 - val_loss: 2.4374 - val_accuracy: 0.2511
# Epoch 59/100
# 175/175 [==============================] - 11s 60ms/step - loss: 2.4133 - accuracy: 0.2636 - val_loss: 2.4372 - val_accuracy: 0.2575
# Epoch 60/100
# 175/175 [==============================] - 10s 60ms/step - loss: 2.4133 - accuracy: 0.2631 - val_loss: 2.4381 - val_accuracy: 0.2529
# Epoch 61/100
# 175/175 [==============================] - 11s 60ms/step - loss: 2.4129 - accuracy: 0.2681 - val_loss: 2.4383 - val_accuracy: 0.2543
# Epoch 62/100
# 175/175 [==============================] - 11s 60ms/step - loss: 2.4127 - accuracy: 0.2631 - val_loss: 2.4377 - val_accuracy: 0.2561
# Epoch 63/100
# 175/175 [==============================] - 10s 60ms/step - loss: 2.4112 - accuracy: 0.2682 - val_loss: 2.4377 - val_accuracy: 0.2511
# Epoch 64/100
# 175/175 [==============================] - 11s 60ms/step - loss: 2.4110 - accuracy: 0.2725 - val_loss: 2.4377 - val_accuracy: 0.2543
# Epoch 65/100
# 175/175 [==============================] - 11s 63ms/step - loss: 2.4114 - accuracy: 0.2707 - val_loss: 2.4389 - val_accuracy: 0.2507
# Epoch 66/100
# 175/175 [==============================] - 11s 61ms/step - loss: 2.4098 - accuracy: 0.2715 - val_loss: 2.4377 - val_accuracy: 0.2543
# Epoch 67/100
# 175/175 [==============================] - 11s 61ms/step - loss: 2.4098 - accuracy: 0.2705 - val_loss: 2.4376 - val_accuracy: 0.2504
# Epoch 68/100
# 175/175 [==============================] - 11s 60ms/step - loss: 2.4094 - accuracy: 0.2741 - val_loss: 2.4376 - val_accuracy: 0.2532
# Epoch 69/100
# 175/175 [==============================] - 11s 60ms/step - loss: 2.4085 - accuracy: 0.2724 - val_loss: 2.4377 - val_accuracy: 0.2479
# Epoch 70/100
# 175/175 [==============================] - 11s 61ms/step - loss: 2.4078 - accuracy: 0.2768 - val_loss: 2.4377 - val_accuracy: 0.2514
# Epoch 71/100
# 175/175 [==============================] - 11s 61ms/step - loss: 2.4070 - accuracy: 0.2755 - val_loss: 2.4388 - val_accuracy: 0.2550
# Epoch 72/100
# 175/175 [==============================] - 11s 61ms/step - loss: 2.4080 - accuracy: 0.2759 - val_loss: 2.4384 - val_accuracy: 0.2546
# Epoch 73/100
# 175/175 [==============================] - 11s 60ms/step - loss: 2.4074 - accuracy: 0.2727 - val_loss: 2.4387 - val_accuracy: 0.2568
# Epoch 74/100
# 175/175 [==============================] - 11s 60ms/step - loss: 2.4056 - accuracy: 0.2721 - val_loss: 2.4375 - val_accuracy: 0.2500
# Epoch 75/100
# 175/175 [==============================] - 11s 61ms/step - loss: 2.4056 - accuracy: 0.2732 - val_loss: 2.4385 - val_accuracy: 0.2461
# Epoch 76/100
# 175/175 [==============================] - 10s 60ms/step - loss: 2.4050 - accuracy: 0.2723 - val_loss: 2.4382 - val_accuracy: 0.2536
# Epoch 77/100
# 175/175 [==============================] - 10s 60ms/step - loss: 2.4045 - accuracy: 0.2810 - val_loss: 2.4377 - val_accuracy: 0.2518
# Epoch 78/100
# 175/175 [==============================] - 11s 60ms/step - loss: 2.4041 - accuracy: 0.2770 - val_loss: 2.4382 - val_accuracy: 0.2482
# Epoch 79/100
# 175/175 [==============================] - 11s 61ms/step - loss: 2.4035 - accuracy: 0.2764 - val_loss: 2.4385 - val_accuracy: 0.2500
# Epoch 80/100
# 175/175 [==============================] - 11s 61ms/step - loss: 2.4033 - accuracy: 0.2772 - val_loss: 2.4387 - val_accuracy: 0.2532
# Epoch 81/100
# 175/175 [==============================] - 11s 60ms/step - loss: 2.4026 - accuracy: 0.2784 - val_loss: 2.4391 - val_accuracy: 0.2489
# Epoch 82/100
# 175/175 [==============================] - 11s 60ms/step - loss: 2.4029 - accuracy: 0.2807 - val_loss: 2.4387 - val_accuracy: 0.2479
# Epoch 83/100
# 175/175 [==============================] - 10s 60ms/step - loss: 2.4010 - accuracy: 0.2778 - val_loss: 2.4386 - val_accuracy: 0.2496
# Epoch 84/100
# 175/175 [==============================] - 11s 60ms/step - loss: 2.4008 - accuracy: 0.2829 - val_loss: 2.4384 - val_accuracy: 0.2500
# Epoch 85/100
# 175/175 [==============================] - 11s 60ms/step - loss: 2.3999 - accuracy: 0.2823 - val_loss: 2.4397 - val_accuracy: 0.2425
# Epoch 86/100
# 175/175 [==============================] - 11s 60ms/step - loss: 2.4001 - accuracy: 0.2803 - val_loss: 2.4394 - val_accuracy: 0.2403
# Epoch 87/100
# 175/175 [==============================] - 10s 58ms/step - loss: 2.3994 - accuracy: 0.2747 - val_loss: 2.4390 - val_accuracy: 0.2479
# Epoch 88/100
# 175/175 [==============================] - 10s 58ms/step - loss: 2.3989 - accuracy: 0.2811 - val_loss: 2.4396 - val_accuracy: 0.2421
# Epoch 89/100
# 175/175 [==============================] - 10s 58ms/step - loss: 2.3990 - accuracy: 0.2822 - val_loss: 2.4403 - val_accuracy: 0.2418
# Epoch 90/100
# 175/175 [==============================] - 10s 58ms/step - loss: 2.3981 - accuracy: 0.2800 - val_loss: 2.4386 - val_accuracy: 0.2425
# Epoch 91/100
# 175/175 [==============================] - 10s 58ms/step - loss: 2.3972 - accuracy: 0.2827 - val_loss: 2.4388 - val_accuracy: 0.2418
# Epoch 92/100
# 175/175 [==============================] - 10s 57ms/step - loss: 2.3963 - accuracy: 0.2859 - val_loss: 2.4394 - val_accuracy: 0.2428
# Epoch 93/100
# 175/175 [==============================] - 10s 58ms/step - loss: 2.3971 - accuracy: 0.2845 - val_loss: 2.4389 - val_accuracy: 0.2439
# Epoch 94/100
# 175/175 [==============================] - 10s 58ms/step - loss: 2.3960 - accuracy: 0.2867 - val_loss: 2.4398 - val_accuracy: 0.2368
# Epoch 95/100
# 175/175 [==============================] - 10s 58ms/step - loss: 2.3960 - accuracy: 0.2851 - val_loss: 2.4387 - val_accuracy: 0.2346
# Epoch 96/100
# 175/175 [==============================] - 10s 58ms/step - loss: 2.3953 - accuracy: 0.2883 - val_loss: 2.4387 - val_accuracy: 0.2375
# Epoch 97/100
# 175/175 [==============================] - 10s 58ms/step - loss: 2.3938 - accuracy: 0.2868 - val_loss: 2.4394 - val_accuracy: 0.2371
# Epoch 98/100
# 175/175 [==============================] - 10s 58ms/step - loss: 2.3937 - accuracy: 0.2926 - val_loss: 2.4388 - val_accuracy: 0.2386
# Epoch 99/100
# 175/175 [==============================] - 10s 58ms/step - loss: 2.3927 - accuracy: 0.2847 - val_loss: 2.4394 - val_accuracy: 0.2378
# Epoch 100/100
# 175/175 [==============================] - 10s 57ms/step - loss: 2.3934 - accuracy: 0.2931 - val_loss: 2.4387 - val_accuracy: 0.2364
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 3 of 3). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ../data/models/cqt_chroma_batch64_e100/assets
# INFO:tensorflow:Assets written to: ../data/models/cqt_chroma_batch64_e100/assets

# %%
# loss 遷移のプロット

import matplotlib.pyplot as plt

plot_history(history)

# %%
# 楽曲の出力

import sklearn
from sklearn.metrics.pairwise import cosine_similarity
from keras.models import load_model
import soundfile as sf

model = load_model("../data/models/" + model_name)
file_name = "out_" + model_name
num_clips = 10

def add_fade(x, fadetime, sr):
    ft_len = int(fadetime*sr)
    r = np.arange(0, ft_len)*np.pi/ft_len
    w_fo = (0.5+0.5*np.cos(r))**0.5
    w_fi = (0.5-0.5*np.cos(r))**0.5
    
    x[0:ft_len]        *= w_fi
    x[clip_size-ft_len::] *= w_fo
    return x

def gen_xfade(x_pre, x_next, fadetime, sr):
    ft_len = int(fadetime*sr)
    if x_pre is None:
        xfade = x_next
    else:
        x_pre_begin = x_pre[:x_pre.shape[0] - ft_len]
        x_pre_end = x_pre[x_pre.shape[0] - ft_len:]
        x_pre_len = clip_size
        x_next_len = clip_size
        x_pre_len -= ft_len
        x_next_len -= ft_len
        xfade = np.concatenate((x_pre_begin, np.concatenate((x_pre_end, np.zeros(x_next_len))) + x_next))
    return xfade

def create_music(fname):
    first_index = np.random.randint(0, len(x_test))
    predict_index = first_index
    out = None
    
    for i in range(num_clips):
        print("-- generate " + str(i + 1) + " / " + str(num_clips))
        predict = model.predict(np.array([x_test[predict_index]]))

        index = 0
        similar_index = 0
        cos_sim = -1
        for cqt_chroma in x_test[:, 0:1, :, 0]:
            tmp_sim = cosine_similarity(predict, cqt_chroma) 
            if tmp_sim > cos_sim:
                cos_sim = tmp_sim
                similar_index = index
            index += 1

        print("cos_sim: " + str(cos_sim))
        print("predict: " + str(predict))
        print("x_test[similar_index]: " + str(x_test[similar_index, 0, :, 0]))
        print("similar_index: " + str(similar_index))
        print("--")

        predict_index = similar_index

        tmp = add_fade(clips[predict_index], 0.1, SAMPLING_RATE)
        out = gen_xfade(out, tmp, 0.1, SAMPLING_RATE)
    
    
    sf.write(fname, out, SAMPLING_RATE, subtype="PCM_16")

fname = "../data/out/" + file_name + "_1.wav"
print("creating " + fname + " ...")
create_music(fname)

fname = "../data/out/" + file_name + "_2.wav"
print("creating " + fname + " ...")
create_music(fname)

fname = "../data/out/" + file_name + "_3.wav"
print("creating " + fname + " ...")
create_music(fname)
# Out:
# creating ../data/out/out_cqt_chroma_batch64_e100_1.wav ...
# -- generate 1 / 10
# 1/1 [==============================] - 0s 50ms/step
# cos_sim: [[0.90076566]]
# predict: [[0.09180883 0.12981886 0.09545411 0.05150614 0.04646342 0.07733796
#   0.08386277 0.07555941 0.04411435 0.06849773 0.13120925 0.10436714]]
# x_test[similar_index]: [0.0078125  0.00735696 0.00521596 0.00174423 0.00162895 0.00382456
#  0.00388449 0.00701388 0.         0.00049225 0.00538387 0.00182178]
# similar_index: 855
# --
# -- generate 2 / 10
# 1/1 [==============================] - 0s 14ms/step
# cos_sim: [[0.9311423]]
# predict: [[0.1144672  0.09704629 0.07524858 0.09230603 0.0879209  0.11090416
#   0.09688579 0.1398734  0.04762903 0.04762451 0.05023551 0.0398586 ]]
# x_test[similar_index]: [0.00748178 0.00202232 0.00443623 0.00692387 0.00470614 0.0031587
#  0.0078125  0.00775368 0.00387607 0.00317587 0.00443068 0.0057879 ]
# similar_index: 795
# --
# -- generate 3 / 10
# 1/1 [==============================] - 0s 14ms/step
# cos_sim: [[0.9122147]]
# predict: [[0.08550351 0.10015818 0.14008069 0.12566084 0.10378531 0.05530843
#   0.08925778 0.04419367 0.04853621 0.04137753 0.0766621  0.08947567]]
# x_test[similar_index]: [0.00291156 0.0078125  0.00598334 0.00361668 0.0026267  0.00244084
#  0.00334171 0.         0.         0.00176014 0.00267949 0.00258179]
# similar_index: 65
# --
# -- generate 4 / 10
# 1/1 [==============================] - 0s 14ms/step
# cos_sim: [[0.953582]]
# predict: [[0.08166131 0.09418141 0.11805684 0.09877521 0.08518913 0.05282089
#   0.05119827 0.14137141 0.07261042 0.05817452 0.07364593 0.0723146 ]]
# x_test[similar_index]: [0.00301036 0.00614842 0.00777034 0.00293845 0.00714188 0.0044442
#  0.00209224 0.0078125  0.00228943 0.00429863 0.00570688 0.00259691]
# similar_index: 395
# --
# -- generate 5 / 10
# 1/1 [==============================] - 0s 14ms/step
# cos_sim: [[0.91807336]]
# predict: [[0.08139408 0.13639145 0.07066665 0.04784905 0.05140231 0.11534307
#   0.10579948 0.0910931  0.06756676 0.06053058 0.06338781 0.10857568]]
# x_test[similar_index]: [0.00298202 0.00728578 0.00657254 0.         0.00300881 0.0078125
#  0.0054287  0.00517408 0.         0.00378256 0.         0.00537656]
# similar_index: 2340
# --
# -- generate 6 / 10
# 1/1 [==============================] - 0s 16ms/step
# cos_sim: [[0.9324617]]
# predict: [[0.08347556 0.06882818 0.07052898 0.14840014 0.09523333 0.05100709
#   0.05374401 0.09388646 0.08665732 0.08353355 0.0604941  0.10421114]]
# x_test[similar_index]: [0.00748178 0.00202232 0.00443623 0.00692387 0.00470614 0.0031587
#  0.0078125  0.00775368 0.00387607 0.00317587 0.00443068 0.0057879 ]
# similar_index: 795
# --
# -- generate 7 / 10
# 1/1 [==============================] - 0s 14ms/step
# cos_sim: [[0.9122147]]
# predict: [[0.08550351 0.10015818 0.14008069 0.12566084 0.10378531 0.05530843
#   0.08925778 0.04419367 0.04853621 0.04137753 0.0766621  0.08947567]]
# x_test[similar_index]: [0.00291156 0.0078125  0.00598334 0.00361668 0.0026267  0.00244084
#  0.00334171 0.         0.         0.00176014 0.00267949 0.00258179]
# similar_index: 65
# --
# -- generate 8 / 10
# 1/1 [==============================] - 0s 14ms/step
# cos_sim: [[0.953582]]
# predict: [[0.08166131 0.09418141 0.11805684 0.09877521 0.08518913 0.05282089
#   0.05119827 0.14137141 0.07261042 0.05817452 0.07364593 0.0723146 ]]
# x_test[similar_index]: [0.00301036 0.00614842 0.00777034 0.00293845 0.00714188 0.0044442
#  0.00209224 0.0078125  0.00228943 0.00429863 0.00570688 0.00259691]
# similar_index: 395
# --
# -- generate 9 / 10
# 1/1 [==============================] - 0s 14ms/step
# cos_sim: [[0.91807336]]
# predict: [[0.08139408 0.13639145 0.07066665 0.04784905 0.05140231 0.11534307
#   0.10579948 0.0910931  0.06756676 0.06053058 0.06338781 0.10857568]]
# x_test[similar_index]: [0.00298202 0.00728578 0.00657254 0.         0.00300881 0.0078125
#  0.0054287  0.00517408 0.         0.00378256 0.         0.00537656]
# similar_index: 2340
# --
# -- generate 10 / 10
# 1/1 [==============================] - 0s 17ms/step
# cos_sim: [[0.9324617]]
# predict: [[0.08347556 0.06882818 0.07052898 0.14840014 0.09523333 0.05100709
#   0.05374401 0.09388646 0.08665732 0.08353355 0.0604941  0.10421114]]
# x_test[similar_index]: [0.00748178 0.00202232 0.00443623 0.00692387 0.00470614 0.0031587
#  0.0078125  0.00775368 0.00387607 0.00317587 0.00443068 0.0057879 ]
# similar_index: 795
# --
# creating ../data/out/out_cqt_chroma_batch64_e100_2.wav ...
# -- generate 1 / 10
# 1/1 [==============================] - 0s 15ms/step
# cos_sim: [[0.9626116]]
# predict: [[0.07924047 0.06441179 0.08124869 0.09634353 0.09990878 0.07897627
#   0.10983987 0.08937976 0.05167231 0.06571852 0.0949392  0.08832087]]
# x_test[similar_index]: [0.00748178 0.00202232 0.00443623 0.00692387 0.00470614 0.0031587
#  0.0078125  0.00775368 0.00387607 0.00317587 0.00443068 0.0057879 ]
# similar_index: 795
# --
# -- generate 2 / 10
# 1/1 [==============================] - 0s 15ms/step
# cos_sim: [[0.9122147]]
# predict: [[0.08550351 0.10015818 0.14008069 0.12566084 0.10378531 0.05530843
#   0.08925778 0.04419367 0.04853621 0.04137753 0.0766621  0.08947567]]
# x_test[similar_index]: [0.00291156 0.0078125  0.00598334 0.00361668 0.0026267  0.00244084
#  0.00334171 0.         0.         0.00176014 0.00267949 0.00258179]
# similar_index: 65
# --
# -- generate 3 / 10
# 1/1 [==============================] - 0s 14ms/step
# cos_sim: [[0.953582]]
# predict: [[0.08166131 0.09418141 0.11805684 0.09877521 0.08518913 0.05282089
#   0.05119827 0.14137141 0.07261042 0.05817452 0.07364593 0.0723146 ]]
# x_test[similar_index]: [0.00301036 0.00614842 0.00777034 0.00293845 0.00714188 0.0044442
#  0.00209224 0.0078125  0.00228943 0.00429863 0.00570688 0.00259691]
# similar_index: 395
# --
# -- generate 4 / 10
# 1/1 [==============================] - 0s 14ms/step
# cos_sim: [[0.91807336]]
# predict: [[0.08139408 0.13639145 0.07066665 0.04784905 0.05140231 0.11534307
#   0.10579948 0.0910931  0.06756676 0.06053058 0.06338781 0.10857568]]
# x_test[similar_index]: [0.00298202 0.00728578 0.00657254 0.         0.00300881 0.0078125
#  0.0054287  0.00517408 0.         0.00378256 0.         0.00537656]
# similar_index: 2340
# --
# -- generate 5 / 10
# 1/1 [==============================] - 0s 15ms/step
# cos_sim: [[0.9324617]]
# predict: [[0.08347556 0.06882818 0.07052898 0.14840014 0.09523333 0.05100709
#   0.05374401 0.09388646 0.08665732 0.08353355 0.0604941  0.10421114]]
# x_test[similar_index]: [0.00748178 0.00202232 0.00443623 0.00692387 0.00470614 0.0031587
#  0.0078125  0.00775368 0.00387607 0.00317587 0.00443068 0.0057879 ]
# similar_index: 795
# --
# -- generate 6 / 10
# 1/1 [==============================] - 0s 14ms/step
# cos_sim: [[0.9122147]]
# predict: [[0.08550351 0.10015818 0.14008069 0.12566084 0.10378531 0.05530843
#   0.08925778 0.04419367 0.04853621 0.04137753 0.0766621  0.08947567]]
# x_test[similar_index]: [0.00291156 0.0078125  0.00598334 0.00361668 0.0026267  0.00244084
#  0.00334171 0.         0.         0.00176014 0.00267949 0.00258179]
# similar_index: 65
# --
# -- generate 7 / 10
# 1/1 [==============================] - 0s 14ms/step
# cos_sim: [[0.953582]]
# predict: [[0.08166131 0.09418141 0.11805684 0.09877521 0.08518913 0.05282089
#   0.05119827 0.14137141 0.07261042 0.05817452 0.07364593 0.0723146 ]]
# x_test[similar_index]: [0.00301036 0.00614842 0.00777034 0.00293845 0.00714188 0.0044442
#  0.00209224 0.0078125  0.00228943 0.00429863 0.00570688 0.00259691]
# similar_index: 395
# --
# -- generate 8 / 10
# 1/1 [==============================] - 0s 14ms/step
# cos_sim: [[0.91807336]]
# predict: [[0.08139408 0.13639145 0.07066665 0.04784905 0.05140231 0.11534307
#   0.10579948 0.0910931  0.06756676 0.06053058 0.06338781 0.10857568]]
# x_test[similar_index]: [0.00298202 0.00728578 0.00657254 0.         0.00300881 0.0078125
#  0.0054287  0.00517408 0.         0.00378256 0.         0.00537656]
# similar_index: 2340
# --
# -- generate 9 / 10
# 1/1 [==============================] - 0s 15ms/step
# cos_sim: [[0.9324617]]
# predict: [[0.08347556 0.06882818 0.07052898 0.14840014 0.09523333 0.05100709
#   0.05374401 0.09388646 0.08665732 0.08353355 0.0604941  0.10421114]]
# x_test[similar_index]: [0.00748178 0.00202232 0.00443623 0.00692387 0.00470614 0.0031587
#  0.0078125  0.00775368 0.00387607 0.00317587 0.00443068 0.0057879 ]
# similar_index: 795
# --
# -- generate 10 / 10
# 1/1 [==============================] - 0s 15ms/step
# cos_sim: [[0.9122147]]
# predict: [[0.08550351 0.10015818 0.14008069 0.12566084 0.10378531 0.05530843
#   0.08925778 0.04419367 0.04853621 0.04137753 0.0766621  0.08947567]]
# x_test[similar_index]: [0.00291156 0.0078125  0.00598334 0.00361668 0.0026267  0.00244084
#  0.00334171 0.         0.         0.00176014 0.00267949 0.00258179]
# similar_index: 65
# --
# creating ../data/out/out_cqt_chroma_batch64_e100_3.wav ...
# -- generate 1 / 10
# 1/1 [==============================] - 0s 15ms/step
# cos_sim: [[0.9388623]]
# predict: [[0.1089309  0.14937401 0.09725147 0.12400885 0.06457718 0.05727992
#   0.06318109 0.08433536 0.0394582  0.04515437 0.05686386 0.10958482]]
# x_test[similar_index]: [0.00764787 0.0078125  0.00673734 0.00393042 0.00325949 0.00291216
#  0.00291992 0.00387269 0.         0.00267995 0.         0.00357459]
# similar_index: 2412
# --
# -- generate 2 / 10
# 1/1 [==============================] - 0s 14ms/step
# cos_sim: [[0.94971627]]
# predict: [[0.14495672 0.12615001 0.1125881  0.10142265 0.10543973 0.07482664
#   0.04991656 0.05073601 0.04144381 0.04000369 0.04318078 0.10933529]]
# x_test[similar_index]: [0.00764787 0.0078125  0.00673734 0.00393042 0.00325949 0.00291216
#  0.00291992 0.00387269 0.         0.00267995 0.         0.00357459]
# similar_index: 2412
# --
# -- generate 3 / 10
# 1/1 [==============================] - 0s 14ms/step
# cos_sim: [[0.94971627]]
# predict: [[0.14495672 0.12615001 0.1125881  0.10142265 0.10543973 0.07482664
#   0.04991656 0.05073601 0.04144381 0.04000369 0.04318078 0.10933529]]
# x_test[similar_index]: [0.00764787 0.0078125  0.00673734 0.00393042 0.00325949 0.00291216
#  0.00291992 0.00387269 0.         0.00267995 0.         0.00357459]
# similar_index: 2412
# --
# -- generate 4 / 10
# 1/1 [==============================] - 0s 14ms/step
# cos_sim: [[0.94971627]]
# predict: [[0.14495672 0.12615001 0.1125881  0.10142265 0.10543973 0.07482664
#   0.04991656 0.05073601 0.04144381 0.04000369 0.04318078 0.10933529]]
# x_test[similar_index]: [0.00764787 0.0078125  0.00673734 0.00393042 0.00325949 0.00291216
#  0.00291992 0.00387269 0.         0.00267995 0.         0.00357459]
# similar_index: 2412
# --
# -- generate 5 / 10
# 1/1 [==============================] - 0s 14ms/step
# cos_sim: [[0.94971627]]
# predict: [[0.14495672 0.12615001 0.1125881  0.10142265 0.10543973 0.07482664
#   0.04991656 0.05073601 0.04144381 0.04000369 0.04318078 0.10933529]]
# x_test[similar_index]: [0.00764787 0.0078125  0.00673734 0.00393042 0.00325949 0.00291216
#  0.00291992 0.00387269 0.         0.00267995 0.         0.00357459]
# similar_index: 2412
# --
# -- generate 6 / 10
# 1/1 [==============================] - 0s 14ms/step
# cos_sim: [[0.94971627]]
# predict: [[0.14495672 0.12615001 0.1125881  0.10142265 0.10543973 0.07482664
#   0.04991656 0.05073601 0.04144381 0.04000369 0.04318078 0.10933529]]
# x_test[similar_index]: [0.00764787 0.0078125  0.00673734 0.00393042 0.00325949 0.00291216
#  0.00291992 0.00387269 0.         0.00267995 0.         0.00357459]
# similar_index: 2412
# --
# -- generate 7 / 10
# 1/1 [==============================] - 0s 14ms/step
# cos_sim: [[0.94971627]]
# predict: [[0.14495672 0.12615001 0.1125881  0.10142265 0.10543973 0.07482664
#   0.04991656 0.05073601 0.04144381 0.04000369 0.04318078 0.10933529]]
# x_test[similar_index]: [0.00764787 0.0078125  0.00673734 0.00393042 0.00325949 0.00291216
#  0.00291992 0.00387269 0.         0.00267995 0.         0.00357459]
# similar_index: 2412
# --
# -- generate 8 / 10
# 1/1 [==============================] - 0s 15ms/step
# cos_sim: [[0.94971627]]
# predict: [[0.14495672 0.12615001 0.1125881  0.10142265 0.10543973 0.07482664
#   0.04991656 0.05073601 0.04144381 0.04000369 0.04318078 0.10933529]]
# x_test[similar_index]: [0.00764787 0.0078125  0.00673734 0.00393042 0.00325949 0.00291216
#  0.00291992 0.00387269 0.         0.00267995 0.         0.00357459]
# similar_index: 2412
# --
# -- generate 9 / 10
# 1/1 [==============================] - 0s 15ms/step
# cos_sim: [[0.94971627]]
# predict: [[0.14495672 0.12615001 0.1125881  0.10142265 0.10543973 0.07482664
#   0.04991656 0.05073601 0.04144381 0.04000369 0.04318078 0.10933529]]
# x_test[similar_index]: [0.00764787 0.0078125  0.00673734 0.00393042 0.00325949 0.00291216
#  0.00291992 0.00387269 0.         0.00267995 0.         0.00357459]
# similar_index: 2412
# --
# -- generate 10 / 10
# 1/1 [==============================] - 0s 14ms/step
# cos_sim: [[0.94971627]]
# predict: [[0.14495672 0.12615001 0.1125881  0.10142265 0.10543973 0.07482664
#   0.04991656 0.05073601 0.04144381 0.04000369 0.04318078 0.10933529]]
# x_test[similar_index]: [0.00764787 0.0078125  0.00673734 0.00393042 0.00325949 0.00291216
#  0.00291992 0.00387269 0.         0.00267995 0.         0.00357459]
# similar_index: 2412
# --
